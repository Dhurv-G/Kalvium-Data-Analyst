# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_election_results(url, table_class):
    # Make a GET request to the URL
    response = requests.get(url)
    data = []

    try:
        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find the table with the results
            table = soup.find('table', {'class': table_class})

            # Extract table headers
            headers = [header.get_text(strip=True) for header in table.find('thead').find_all('th')]
            headers.append('Link')  # Add a new header for the links

            # Extract table rows
            rows = table.find('tbody').find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                row_data = {headers[i]: cols[i].get_text(strip=True) for i in range(len(headers) - 1)}

                # Check for anchor tags and add the link to the row data
                for col in cols:
                    link_tag = col.find('a')
                    if link_tag:
                        row_data['Link'] = link_tag['href']
                        break  # Assuming one link per row, break after finding the first link

                else:
                    row_data['Link'] = None  # If no link is found, set to None

                data.append(row_data)

            # Create DataFrame from the data
            df = pd.DataFrame(data)
            df['Link']= row_data['Link']='https://results.eci.gov.in/PcResultGenJune2024/'+df['Link']
            return df
        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(e)
        return None

# %%
url = 'https://results.eci.gov.in/PcResultGenJune2024/partywisewinresultState-369.htm'  # Replace with the actual URL
table_class = 'table table-striped table-bordered'  # Replace with the actual class name
df2 = scrape_election_results(url, table_class)
df2
# Out:
#     S.No Parliament Constituency                            Winning Candidate  \
# 0      1           Anakapalle(5)                                   C.M.RAMESH
# 1      2          Rajahmundry(8)                     DAGGUBATI PURANDHESHWARI
# 2      3           Narsapuram(9)  BHUPATHI RAJU SRINIVASA VARMA (B.J.P.VARMA)
# 3      4       Arunachal West(1)                                 KIREN RIJIJU
# 4      5       Arunachal East(2)                                    TAPIR GAO
# ..   ...                     ...                                          ...
# 235  236     North-West Delhi(5)                          YOGENDER CHANDOLIYA
# 236  237           West Delhi(6)                           KAMALJEET SEHRAWAT
# 237  238          South Delhi(7)                         RAMVIR SINGH BIDHURI
# 238  239             UDHAMPUR(4)                            DR JITENDRA SINGH
# 239  240                JAMMU(5)                                JUGAL KISHORE
#
#     Total Votes  Margin                                               Link
# 0        762069  296530  https://results.eci.gov.in/PcResultGenJune2024...
# 1        726515  239139  https://results.eci.gov.in/PcResultGenJune2024...
# 2        707343  276802  https://results.eci.gov.in/PcResultGenJune2024...
# 3        205417  100738  https://results.eci.gov.in/PcResultGenJune2024...
# 4        145581   30421  https://results.eci.gov.in/PcResultGenJune2024...
# ..          ...     ...                                                ...
# 235      866483  290849  https://results.eci.gov.in/PcResultGenJune2024...
# 236      842658  199013  https://results.eci.gov.in/PcResultGenJune2024...
# 237      692832  124333  https://results.eci.gov.in/PcResultGenJune2024...
# 238      571076  124373  https://results.eci.gov.in/PcResultGenJune2024...
# 239      687588  135498  https://results.eci.gov.in/PcResultGenJune2024...
#
# [240 rows x 6 columns]

# %%
df2.to_csv('election_results_PC_INDV.csv', index=False)

# %%
df2
# Out:
#     S.No Parliament Constituency                            Winning Candidate  \
# 0      1           Anakapalle(5)                                   C.M.RAMESH
# 1      2          Rajahmundry(8)                     DAGGUBATI PURANDHESHWARI
# 2      3           Narsapuram(9)  BHUPATHI RAJU SRINIVASA VARMA (B.J.P.VARMA)
# 3      4       Arunachal West(1)                                 KIREN RIJIJU
# 4      5       Arunachal East(2)                                    TAPIR GAO
# ..   ...                     ...                                          ...
# 235  236     North-West Delhi(5)                          YOGENDER CHANDOLIYA
# 236  237           West Delhi(6)                           KAMALJEET SEHRAWAT
# 237  238          South Delhi(7)                         RAMVIR SINGH BIDHURI
# 238  239             UDHAMPUR(4)                            DR JITENDRA SINGH
# 239  240                JAMMU(5)                                JUGAL KISHORE
#
#     Total Votes  Margin                                               Link
# 0        762069  296530  https://results.eci.gov.in/PcResultGenJune2024...
# 1        726515  239139  https://results.eci.gov.in/PcResultGenJune2024...
# 2        707343  276802  https://results.eci.gov.in/PcResultGenJune2024...
# 3        205417  100738  https://results.eci.gov.in/PcResultGenJune2024...
# 4        145581   30421  https://results.eci.gov.in/PcResultGenJune2024...
# ..          ...     ...                                                ...
# 235      866483  290849  https://results.eci.gov.in/PcResultGenJune2024...
# 236      842658  199013  https://results.eci.gov.in/PcResultGenJune2024...
# 237      692832  124333  https://results.eci.gov.in/PcResultGenJune2024...
# 238      571076  124373  https://results.eci.gov.in/PcResultGenJune2024...
# 239      687588  135498  https://results.eci.gov.in/PcResultGenJune2024...
#
# [240 rows x 6 columns]

# %%
df3 = pd.read_csv('election_results_PC_INDV.csv')

# %%
df3
# Out:
#      S.No Parliament Constituency  \
# 0       1           Anakapalle(5)
# 1       2          Rajahmundry(8)
# 2       3           Narsapuram(9)
# 3       4       Arunachal West(1)
# 4       5       Arunachal East(2)
# ..    ...                     ...
# 235   236     North-West Delhi(5)
# 236   237           West Delhi(6)
# 237   238          South Delhi(7)
# 238   239             UDHAMPUR(4)
# 239   240                JAMMU(5)
#
#                                Winning Candidate Total Votes  Margin  \
# 0                                     C.M.RAMESH      762069  296530
# 1                       DAGGUBATI PURANDHESHWARI      726515  239139
# 2    BHUPATHI RAJU SRINIVASA VARMA (B.J.P.VARMA)      707343  276802
# 3                                   KIREN RIJIJU      205417  100738
# 4                                      TAPIR GAO      145581   30421
# ..                                           ...         ...     ...
# 235                          YOGENDER CHANDOLIYA      866483  290849
# 236                           KAMALJEET SEHRAWAT      842658  199013
# 237                         RAMVIR SINGH BIDHURI      692832  124333
# 238                            DR JITENDRA SINGH      571076  124373
# 239                                JUGAL KISHORE      687588  135498
#
#                                                   Link
# 0    https://results.eci.gov.in/PcResultGenJune2024...
# 1    https://results.eci.gov.in/PcResultGenJune2024...
# 2    https://results.eci.gov.in/PcResultGenJune2024...
# 3    https://results.eci.gov.in/PcResultGenJune2024...
# 4    https://results.eci.gov.in/PcResultGenJune2024...
# ..                                                 ...
# 235  https://results.eci.gov.in/PcResultGenJune2024...
# 236  https://results.eci.gov.in/PcResultGenJune2024...
# 237  https://results.eci.gov.in/PcResultGenJune2024...
# 238  https://results.eci.gov.in/PcResultGenJune2024...
# 239  https://results.eci.gov.in/PcResultGenJune2024...
#
# [240 rows x 6 columns]
